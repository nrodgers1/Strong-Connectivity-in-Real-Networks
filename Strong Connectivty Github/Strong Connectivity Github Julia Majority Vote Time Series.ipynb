# %%
using LightGraphs, GraphIO, GraphPlot, NetworkDynamics, OrdinaryDiffEq, Plots,  Printf


#f=open("net_celegans_neural.dat")

# %%
using LinearAlgebra, IterativeSolvers, Statistics

function get_levels(A)
    
    #A= convert(SparseMatrixCSC{Float64}, A)
    A= convert(Array{Float64}, A)
    
    w_in = vec(sum(A, dims=1))
   
    w_out= vec(sum(A, dims=2))
    
   
    
    u = w_in + w_out 
    
    v= w_in - w_out 
   
    Lambda=  diagm(u)-  A - transpose(A)
    
   
    Lambda[1,1]= 0 
    
    h= bicgstabl(Lambda, v, 10)
    #h=  lsmr(Lambda, v)   
       
    h= h .- minimum(h)
    
    return h
end
# Out:
# get_levels (generic function with 1 method)

# %%
function calc_troph_incoh(A,h)
    
    F=0

    for (x,y,v) in zip(findnz(A)...)
  
    
        F = F + v*(h[y] - h[x] -1 )^2
        
    end
    
    F= F/sum(A)
    
end
# Out:
# calc_troph_incoh (generic function with 1 method)

# %%
using SparseArrays


function maj_vote_update(x,g,N)
    
    
    x_old= copy(x)
        for i in 1:N
        
        in_connections= inneighbors(g,i)
        
        sums = 0
        for v in in_connections
        sums= sums + x_old[v]
        end
        
        x[i] = sign(sums + 0.05*x_old[i]) 
    
        #if x[i]==0
            #x[i]= sign(rand() - 0.5)
        #end
        
    end
    
    return x
end
# Out:
# maj_vote_update (generic function with 1 method)

# %%
function sis_update(x,g,N,pI,pR)
    
    
    x_new= copy(x)
    
    for i in 1:N
        
        in_connections= inneighbors(g,i)
        
       prob= rand() 
        
        
        if x[i]==1
           
         if pR> prob
                
           #println("Here") 
           x_new[i]= 0
            
            end
            
            
        else
        
        sums = 0
        for v in in_connections
        sums= sums= sums + x[v]
        end
            
          if sums>0
               
            if pI> prob
                
            
           x_new[i]= 1
              #println("Here")   
            end
                
                
            end
            
            
        end
        
        
        
       
        
    end
    
    
    x= copy(x_new)
    
    
    return x
    
end
# Out:
# sis_update (generic function with 1 method)

# %%
using LinearAlgebra, OrdinaryDiffEq, Random
using Arpack
using SNAPDatasets


number=200



updates=20

#T_list= LinRange(0.025, 8, number)




#T_list= 1.2*ones(number)

B=0

F_list = zeros(0)





time = LinRange(0, updates, updates)



state_list = zeros(0)


#stop = 5

#w_in=1

#net_celegans_neural.dat

#g = loadsnap(:soc_slashdot0902_d)

#g = loadgraph("net_celegans_neural.dat", "SimpleDiGraph", EdgeListFormat())
#g = loadgraph("wiki-Vote.txt", "SimpleDiGraph", EdgeListFormat())



#g = loadgraph("soc-Slashdot0902.txt", "SimpleDiGraph", EdgeListFormat())

#g = loadgraph("net_moreno_highschool.dat", "SimpleDiGraph", EdgeListFormat())    
g= erdos_renyi(1000, 10*1000, is_directed=true)    
N=nv(g)    
A = ((adjacency_matrix(g)))    

println("Loaded") 
    
    
h = get_levels(A)
    
F= calc_troph_incoh(A,h)    
append!( F_list, F )  
    
#println(maximum(real(eigvals(Matrix(A)))))

    
 
pI = 0.2

pR = 0.1
    

    
#x0 =  zeros(0) 
    

frac= floor(Int,0.2*N)
    
for i in 1:N
        
      append!(x0, (sign(h[i] - frac )) ) 
        
        
    end

sorted = reverse(sortperm(h))    
    

    
    
x0= ones(N)
   
   
for b in 1:frac
  
    x0[sorted[b]]= -1
    
    
    #println(h[sorted[b]])
    end

    
x= copy(x0) 




for i in 1:updates
        
     x = maj_vote_update(x,g,N)
       
        
      append!(state_list, sum(x))    
        
    end
        
        
        
    
  
    
    
    
println("Done 1 Update")
# Out:
# Loaded
# Done 1 Update

# %%
using Polynomials, SpecialFunctions




g1= copy(g)

g2=copy(g)

strong_list = zeros(0)

strong_list_rand = zeros(0) 


using LinearAlgebra
using Arpack

N=size(A)[1]
println(N)
diffs= zeros(0)
edge_rem= 0

x_list= zeros(0)
y_list =zeros(0)

for (c,y,v) in zip(findnz(A)...)
  
    
        d= (h[y] - h[c] )
        append!(diffs,d)
        append!(x_list,c)
        append!(y_list,y)
       
    end


L= sum(A)

#println(diffs)

j = (sortperm(diffs))

x_list= floor.(Int,x_list[j])

y_list=  floor.(Int,y_list[j])


arg= - sqrt(-F +1)/(F*(2)) 

erf_function= 0.5*(1 + erf(arg))

beta = erf_function 

rand_j= shuffle(j)



x_list_rand= (x_list[rand_j])

y_list_rand= (y_list[rand_j])

#println(diffs[j])

weak_list= zeros(0)
weak_rand=zeros(0)


L_list=zeros(0)
#for i in 1:(floor(Int,beta*L))
    
for i in 1:(floor(Int,L*0.2))
    #println(i)
    #strong = strongly_connected_components(g1)   
    #append!(strong_list, maximum(size.(strong))[1]/N)
    
    #weak = weakly_connected_components(g1)
    #append!(weak_list, maximum(size.(weak))[1]/N)
    rem_edge!(g1, x_list[i],y_list[i])
    
     #strong_rand = strongly_connected_components(g2)   
    #append!(strong_list_rand, maximum(size.(strong_rand))[1]/N)
    #weak_2 = weakly_connected_components(g2)
    #append!(weak_rand, maximum(size.(weak_2))[1]/N)
    
    rem_edge!(g2, x_list_rand[i],y_list_rand[i])
    
    
    #append!(L_list, i)
end


L_list= L_list/L


x0= ones(N)
   
sorted = (sortperm(h))     
for b in 1:frac
  
    x0[sorted[b]]= -1
    
    
    #println(h[sorted[b]])
    end

    
x= copy(x0) 



x= copy(x0) 


state_no_back = zeros(0)

for i in 1:updates
        
     x = maj_vote_update(x,g1,N)
       
        
      append!(state_no_back, sum(x))    
        
    end
# Out:
# 1000

# %%
x0= ones(N)
   
sorted = reverse(sortperm(h))     
for b in 1:frac
  
    x0[sorted[b]]= -1
    
    
    #println(h[sorted[b]])
    end

    
x= copy(x0) 



x= copy(x0) 


state_no_back_top = zeros(0)

for i in 1:updates
        
     x = maj_vote_update(x,g1,N)
       
        
      append!(state_no_back_top, sum(x))    
        
    end

# %%
sorted = (sortperm(h))  

state_low = zeros(0)
x0= ones(N)
   
    
for b in 1:frac
  
    x0[sorted[b]]= -1
    
    
    #println(h[sorted[b]])
    end

    
x= copy(x0) 




for i in 1:updates
        
     x = maj_vote_update(x,g,N)
       
        
      append!(state_low, sum(x))    
        
    end

# %%
x0= ones(N)

sorted = reverse(sortperm(h))     
for b in 1:frac
  
    x0[sorted[b]]= -1
    
    
    #println(h[sorted[b]])
    end

    




x= copy(x0) 


state_random_removed_high = zeros(0)

for i in 1:updates
        
     x = maj_vote_update(x,g2,N)
       
        
      append!(state_random_removed_high, sum(x))    
        
    end

# %%
x0= ones(N)

sorted = (sortperm(h))     
for b in 1:frac
  
    x0[sorted[b]]= -1
    
    
    #println(h[sorted[b]])
    end

    
x= copy(x0) 






state_random_removed = zeros(0)

for i in 1:updates
        
     x = maj_vote_update(x,g2,N)
       
        
      append!(state_random_removed, sum(x))    
        
    end

# %%
plot(time,state_random_removed_high./N, legend=:right,label="Random: High Level Start",lw=2, ylabel="Average Opinion")

plot!(time,state_random_removed./N, label="Random: Low level start", lw=2)


plot!(time,state_no_back_top./N, label="Back Edges: High level start", lw=2)

plot!(time,state_no_back./N, label="Back Edges: Low level start",lw=2, xlabel="Timesteps")



#savefig("Random_Graph_maj_vote_time_series.pdf")

# %%
plot(time,state_list./N, legend=:right,label="Full Network: High Level Start",lw=2, ylabel="Fraction of Infected Nodes")

plot!(time,state_low./N, label="Full Network: Low level start", lw=2)


plot!(time,state_no_back_top./N, label="Back Edges Removed: High level start", lw=2)

plot!(time,state_no_back./N, label="Back Edges Removed: Low level start",lw=2, xlabel="Timesteps")






#savefig("SIS_demonstration_2.pdf")

# %%
strong = strongly_connected_components(g1)   
maximum(size.(strong))[1]
# Out:
# 908

# %%
strongly_connected_components(g1)
# Out:
# 93-element Vector{Vector{Int64}}:
#  [378]
#  [876]
#  [926]
#  [927]
#  [69]
#  [752]
#  [692]
#  [180]
#  [64]
#  [443]
#  [778]
#  [563]
#  [318]
#  ⋮
#  [740]
#  [749]
#  [757]
#  [770]
#  [849]
#  [864]
#  [893]
#  [928]
#  [917]
#  [961]
#  [966]
#  [987]

# %%
plot(L_list, strong_list, label="Trophic",color="red", xlabel="Fraction of Edges Removed", ylabel="Largest Strongly Connected Componenet")

# %%
using Plots

plot(T_list,F_list, seriestype = :scatter, legend = false, xlabel= "Temperatue",

ylabel="Trophic Incoherence", title= "Julia Network Generation")

#savefig("Julia_generation_log_space.pdf")
# Out:
# UndefVarError: T_list not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[17]:3
#  [2] eval
#    @ ./boot.jl:360 [inlined]
#  [3] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base ./loading.jl:1094

# %%
#println(eig_list)

plot(F_list, eig_list, seriestype = :scatter, legend = false, xlabel= "Trophic Incoherence",

ylabel="Spectral Radius", title= "Spectral Radius")


#savefig("Julia_generation_Spec_radius_logspace_2.pdf")
# Out:
# UndefVarError: eig_list not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[18]:3
#  [2] eval
#    @ ./boot.jl:360 [inlined]
#  [3] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base ./loading.jl:1094

# %%
plot(F_list, state_list/N, seriestype = :scatter, legend = false, xlabel= "Trophic Incoherence",

ylabel="Average State of System", title= "Majority Vote Dynamics", ylim=(-1.05,1.05))


#savefig("Majority_Vote_N_500_lowest_5_percent_GRS3.pdf")
# Out:
# DivideError: integer division error
#
# Stacktrace:
#   [1] div
#     @ ./int.jl:261 [inlined]
#   [2] div
#     @ ./div.jl:217 [inlined]
#   [3] div
#     @ ./div.jl:262 [inlined]
#   [4] fld
#     @ ./div.jl:228 [inlined]
#   [5] mod
#     @ ./int.jl:253 [inlined]
#   [6] mod1
#     @ ./operators.jl:781 [inlined]
#   [7] mod
#     @ ./range.jl:1155 [inlined]
#   [8] _cycle
#     @ ~/.julia/packages/Plots/YVapH/src/utils.jl:158 [inlined]
#   [9] gr_draw_markers(series::Plots.Series, x::Vector{Float64}, y::Vector{Float64}, clims::Tuple{Float64, Float64}, msize::Int64, strokewidth::Int64)
#     @ Plots ~/.julia/packages/Plots/YVapH/src/backends/gr.jl:1770
#  [10] gr_draw_markers(series::Plots.Series, x::Vector{Float64}, y::Vector{Float64}, clims::Tuple{Float64, Float64})
#     @ Plots ~/.julia/packages/Plots/YVapH/src/backends/gr.jl:1757
#  [11] gr_add_series(sp::Plots.Subplot{Plots.GRBackend}, series::Plots.Series)
#     @ Plots ~/.julia/packages/Plots/YVapH/src/backends/gr.jl:1643
#  [12] gr_display(sp::Plots.Subplot{Plots.GRBackend}, w::Measures.AbsoluteLength, h::Measures.AbsoluteLength, viewport_canvas::Vector{Float64})
#     @ Plots ~/.julia/packages/Plots/YVapH/src/backends/gr.jl:955
#  [13] gr_display(plt::Plots.Plot{Plots.GRBackend}, fmt::String)
#     @ Plots ~/.julia/packages/Plots/YVapH/src/backends/gr.jl:646
#  [14] _show(io::IOBuffer, #unused#::MIME{Symbol("image/svg+xml")}, plt::Plots.Plot{Plots.GRBackend})
#     @ Plots ~/.julia/packages/Plots/YVapH/src/backends/gr.jl:1897
#  [15] show(io::IOBuffer, m::MIME{Symbol("image/svg+xml")}, plt::Plots.Plot{Plots.GRBackend})
#     @ Plots ~/.julia/packages/Plots/YVapH/src/output.jl:215
#  [16] sprint(::Function, ::MIME{Symbol("image/svg+xml")}, ::Vararg{Any, N} where N; context::Nothing, sizehint::Int64)
#     @ Base ./strings/io.jl:105
#  [17] sprint
#     @ ./strings/io.jl:101 [inlined]
#  [18] _ijulia_display_dict(plt::Plots.Plot{Plots.GRBackend})
#     @ Plots ~/.julia/packages/Plots/YVapH/src/ijulia.jl:53
#  [19] display_dict(plt::Plots.Plot{Plots.GRBackend})
#     @ Plots ~/.julia/packages/Plots/YVapH/src/init.jl:77
#  [20] #invokelatest#2
#     @ ./essentials.jl:708 [inlined]
#  [21] invokelatest
#     @ ./essentials.jl:706 [inlined]
#  [22] execute_request(socket::ZMQ.Socket, msg::IJulia.Msg)
#     @ IJulia ~/.julia/packages/IJulia/e8kqU/src/execute_request.jl:112
#  [23] #invokelatest#2
#     @ ./essentials.jl:708 [inlined]
#  [24] invokelatest
#     @ ./essentials.jl:706 [inlined]
#  [25] eventloop(socket::ZMQ.Socket)
#     @ IJulia ~/.julia/packages/IJulia/e8kqU/src/eventloop.jl:8
#  [26] (::IJulia.var"#15#18")()
#     @ IJulia ./task.jl:411

# %%
plot(F_list, cos.(phase_list), seriestype = :scatter, legend = false, xlabel= "Trophic Incoherence",

ylabel="Cosine of Average Phase", title= "Final Phase when the lowest tenth modified")

#savefig("Kuramoto_0.1_controls_dynamics_2.pdf")
# Out:
# UndefVarError: phase_list not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[20]:1
#  [2] eval
#    @ ./boot.jl:360 [inlined]
#  [3] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base ./loading.jl:1094

# %%
plot(eig_list, r_list, seriestype = :scatter, legend = false, xlabel= "Spectral Radius",

ylabel="R Phase Coherence", title= "Oscillator Synchronization Spectral Radius")
# Out:
# UndefVarError: eig_list not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[21]:1
#  [2] eval
#    @ ./boot.jl:360 [inlined]
#  [3] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base ./loading.jl:1094
